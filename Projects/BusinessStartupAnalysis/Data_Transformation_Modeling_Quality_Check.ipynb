# %% [markdown]
# # 2. Data Transformation, Modeling, and Quality with Spark

# %% [markdown]
# After exploring the data, I will transform (reshaping, joining, filtering) the datasets so they will be ready for use in a Data Model.
# This is a continuation from the Data Exploration notebook, so I will be using the same datasets: WDICountry.csv, WDIData.csv, and WDISeries.csv

# %%
# %%bash
# ls ./Downloads/WDI_csv/
# Out:
# WDICountry-Series.csv
# WDICountry.csv
# WDIData.csv
# WDIFootNote.csv
# WDISeries-Time.csv
# WDISeries.csv

# %%
import os
from IPython.display import display, HTML
import pandas as pd
import pyspark 
from pyspark.sql import functions as F
from pyspark.sql.types import DecimalType

#import modules needed for pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Data Transformation").getOrCreate()

# %%
#a function to format Spark DataFrames clearly
def showDF(df, limitRows =  15, truncate = True):
    if(truncate):
        pd.set_option('display.max_colwidth', 50)
        display(df.limit(limitRows).toPandas())
    else:
        pd.set_option('display.max_colwidth', -1)
        pd.set_option('display.max_rows', limitRows)
        display(df.limit(limitRows).toPandas())
        pd.reset_option('display.max_rows')

# %% [markdown]
# #### Read the files into Spark DataFrames

# %%
country = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("./Downloads/WDI_csv/WDICountry.csv")

country.count()
# Out:
# 263

# %%
series = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("./Downloads/WDI_csv/WDIseries.csv")

series.count()
# Out:
# 1437

# %%
indicators = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("./Downloads/WDI_csv/WDIData.csv")

indicators.count()
# Out:
# 377256

# %% [markdown]
# ### Transforming the data
# #### Starting with the Country DataFrame:
# - Remove unwanted columns for the data model
# - Rename columns for data indigestion

# %%
countryRenamed = country \
    .select("2-alpha code", "Country Code", "Short Name", "Long Name", "Region", "Income Group") \
    .withColumnRenamed("2-alpha code", "country_iso_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .withColumnRenamed("Short Name", "country_name") \
    .withColumnRenamed("Long Name", "country_long_name") \
    .withColumnRenamed("Region", "region") \
    .withColumnRenamed("Income Group", "income_group")

# %%
#Register the DataFrame as a global temporary view for SQL queries
countryRenamed.createOrReplaceTempView("country")

# %% [markdown]
# #### First 15 rows of the Country dataset with renamed columns:

# %%
renamedDF = """
select 
    country_iso_code,
    wb_country_code,
    country_name as name,
    country_long_name as long_name,
    region,
    income_group
from 
    country
"""

showDF(spark.sql(renamedDF))
# Out:
#    country_iso_code wb_country_code                  name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
#
#                        long_name                      region  \
# 0                          Aruba   Latin America & Caribbean
# 1   Islamic State of Afghanistan                  South Asia
# 2    People's Republic of Angola          Sub-Saharan Africa
# 3            Republic of Albania       Europe & Central Asia
# 4        Principality of Andorra       Europe & Central Asia
# 5                     Arab World                        None
# 6           United Arab Emirates  Middle East & North Africa
# 7             Argentine Republic   Latin America & Caribbean
# 8            Republic of Armenia       Europe & Central Asia
# 9                 American Samoa         East Asia & Pacific
# 10           Antigua and Barbuda   Latin America & Caribbean
# 11     Commonwealth of Australia         East Asia & Pacific
# 12           Republic of Austria       Europe & Central Asia
# 13        Republic of Azerbaijan       Europe & Central Asia
# 14           Republic of Burundi          Sub-Saharan Africa
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7   Upper middle income
# 8   Upper middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income

# %% [markdown]
# ### Quality Check
# #### Do all countries have 2 character country_iso_codes?
# The number of countries with 2 character iso codes (262) differ from the number or rows of the Country dataset (263)

# %%
isoLength = """
select 
    length(country_iso_code) as characters,
    count(1) as count
from 
    country
group by 
    characters
having 
    count > 1
"""

showDF(spark.sql(isoLength))
# Out:
#    characters  count
# 0           2    262

# %% [markdown]
# #### Check for duplicates for any of the key columns
# There are no duplicates

# %%
isoDuplicates = """
select 
    country_iso_code,
    count(1) as count
from
    country
group by
    country_iso_code
having
    count > 1
    
"""
showDF(spark.sql(isoDuplicates))

wbDuplicates = """
select 
    country_iso_code,
    count(1) as count
from
    country
group by
    country_iso_code
having
    count > 1
    
"""
showDF(spark.sql(wbDuplicates))

nameDuplicates = """
select 
    country_iso_code,
    count(1) as count
from
    country
group by
    country_iso_code
having
    count > 1
    
"""

showDF(spark.sql(nameDuplicates))
# Out:
# Empty DataFrame
# Columns: [country_iso_code, count]
# Index: []
# Empty DataFrame
# Columns: [country_iso_code, count]
# Index: []
# Empty DataFrame
# Columns: [country_iso_code, count]
# Index: []

# %% [markdown]
# #### The reason is because one of the iso codes are null

# %%
isoLength2 = """
select 
    length(country_iso_code) as characters,
    count(1) as count
from 
    country
group by 
    characters
"""

showDF(spark.sql(isoLength2))
# Out:
#    characters  count
# 0         NaN      1
# 1         2.0    262

# %% [markdown]
# #### After removing the null iso code, the numbers of rows is the same as the number of iso codes that are > 2 characters in length. (262)

# %%
countryFinal = countryRenamed.filter("country_iso_code is not null")

showDF(countryFinal)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
#
#                country_long_name                      region  \
# 0                          Aruba   Latin America & Caribbean
# 1   Islamic State of Afghanistan                  South Asia
# 2    People's Republic of Angola          Sub-Saharan Africa
# 3            Republic of Albania       Europe & Central Asia
# 4        Principality of Andorra       Europe & Central Asia
# 5                     Arab World                        None
# 6           United Arab Emirates  Middle East & North Africa
# 7             Argentine Republic   Latin America & Caribbean
# 8            Republic of Armenia       Europe & Central Asia
# 9                 American Samoa         East Asia & Pacific
# 10           Antigua and Barbuda   Latin America & Caribbean
# 11     Commonwealth of Australia         East Asia & Pacific
# 12           Republic of Austria       Europe & Central Asia
# 13        Republic of Azerbaijan       Europe & Central Asia
# 14           Republic of Burundi          Sub-Saharan Africa
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7   Upper middle income
# 8   Upper middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income

# %%
countryFinal.count()
# Out:
# 262

# %% [markdown]
# #### Write the CountryFinal as a csv file to the folder

# %%
countryFinal \
    .coalesce(1) \
    .write.csv('./Downloads/WDI_csv/Final/country', mode='overwrite', header='true')

# %% [markdown]
# #### Check if it is written correctly
# It is!

# %%
# %%bash
# cat ./Downloads/WDI_csv/Final/country/*csv | head
# Out:
# country_iso_code,wb_country_code,country_name,country_long_name,region,income_group
# AW,ABW,Aruba,Aruba,Latin America & Caribbean,High income
# AF,AFG,Afghanistan,Islamic State of Afghanistan,South Asia,Low income
# AO,AGO,Angola,People's Republic of Angola,Sub-Saharan Africa,Lower middle income
# AL,ALB,Albania,Republic of Albania,Europe & Central Asia,Upper middle income
# AD,AND,Andorra,Principality of Andorra,Europe & Central Asia,High income
# 1A,ARB,Arab World,Arab World,"",""
# AE,ARE,United Arab Emirates,United Arab Emirates,Middle East & North Africa,High income
# AR,ARG,Argentina,Argentine Republic,Latin America & Caribbean,Upper middle income
# AM,ARM,Armenia,Republic of Armenia,Europe & Central Asia,Upper middle income

# %% [markdown]
# ### Next, I will do the same for the WDIseries dataset by transforming and performing a data quality check

# %% [markdown]
# #### Renaming the columns and filtering the data by annual periodicity
# This data set has 1416 rows

# %%
seriesAnnual = series \
    .select("Series Code", "Indicator Name", "Periodicity", "Aggregation Method") \
    .withColumnRenamed("Series Code", "indicator_code") \
    .withColumnRenamed("Indicator Name", "indicator_name") \
    .withColumnRenamed("Periodicity", "periodicity") \
    .withColumnRenamed("Aggregation Method", "aggregation_method") \
    .filter(F.col("periodicity") == "Annual") 
    
showDF(seriesAnnual)

seriesAnnual.count()
# Out:
#        indicator_code                                     indicator_name  \
# 0      AG.AGR.TRAC.NO                   Agricultural machinery, tractors
# 1   AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer produc...
# 2      AG.CON.FERT.ZS  Fertilizer consumption (kilograms per hectare ...
# 3      AG.LND.AGRI.K2                         Agricultural land (sq. km)
# 4      AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 5      AG.LND.ARBL.HA                             Arable land (hectares)
# 6   AG.LND.ARBL.HA.PC                  Arable land (hectares per person)
# 7      AG.LND.ARBL.ZS                       Arable land (% of land area)
# 8      AG.LND.CREL.HA            Land under cereal production (hectares)
# 9      AG.LND.CROP.ZS                Permanent cropland (% of land area)
# 10  AG.LND.EL5M.RU.K2  Rural land area where elevation is below 5 met...
# 11  AG.LND.EL5M.RU.ZS  Rural land area where elevation is below 5 met...
# 12  AG.LND.EL5M.UR.K2  Urban land area where elevation is below 5 met...
# 13  AG.LND.EL5M.UR.ZS  Urban land area where elevation is below 5 met...
# 14     AG.LND.EL5M.ZS  Land area where elevation is below 5 meters (%...
#
#    periodicity aggregation_method
# 0       Annual                Sum
# 1       Annual   Weighted average
# 2       Annual   Weighted average
# 3       Annual                Sum
# 4       Annual   Weighted average
# 5       Annual               None
# 6       Annual   Weighted average
# 7       Annual   Weighted average
# 8       Annual                Sum
# 9       Annual   Weighted average
# 10      Annual                Sum
# 11      Annual   Weighted average
# 12      Annual                Sum
# 13      Annual   Weighted average
# 14      Annual   Weighted average
# 1416

# %% [markdown]
# #### I want to measure the cellular and broadband penetration in comparison to the population demographics for each country. This will also bring insights on annual global aggregates

# %%
AggIndicators = seriesAnnual \
    .select("indicator_code", "indicator_name") \
    .filter("lower(aggregation_method) = 'sum'") \
    .filter("lower(indicator_name) like '%population%total%' " + 
            " or lower(indicator_name) like '%cellular%' " +
            " or lower(indicator_name) like '%broadband%'") \
    .filter("lower(indicator_name) not like '%refugee%'") \
    .orderBy("indicator_code") 

#SQL equivalent
# AggIndicators = """

# select 
#     indicator_code, 
#     indicator_name
# from 
#     seriesAnnual
# where 
#     aggregation_method = "Sum" and
#     ((indicator_name like 'Population%' and indicator_name like '%total') or
#     indicator_name like '%broadband%' or
#     indicator_name like '%cellular%') and
#     indicator_name not like '%refugee%'
# order by 
#     indicator_code
# """
showDF(AggIndicators, truncate = False)
# Out:
#    indicator_code                       indicator_name
# 0  IT.CEL.SETS     Mobile cellular subscriptions
# 1  IT.NET.BBND     Fixed broadband subscriptions
# 2  SP.POP.0014.TO  Population ages 0-14, total
# 3  SP.POP.1564.TO  Population ages 15-64, total
# 4  SP.POP.65UP.TO  Population ages 65 and above, total
# 5  SP.POP.TOTL     Population, total

# %% [markdown]
# #### After identifying the indicators of interest, I can find the metrics for each indicator type

# %%
#keep the columns that are relevant for further transformations from the indicators dataset
indicatorsData = indicators \
    .withColumnRenamed("Indicator Code", "indicator_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .drop("Indicator Name") \
    .drop("Country Name") \
    .drop('_c64')

# %%
#joining indiscatorsData with AggIndicators by indicator_code
AggIndicatorsData = indicatorsData.join(
    AggIndicators, indicatorsData.indicator_code == AggIndicators.indicator_code) \
    .drop(AggIndicators.indicator_code)

#SQL equivalent
# AggIndicatorsData = """
# select 
#     *
# from 
#     AggIndicators
# inner join
#     indicatorsData on AggIndicators.indicator_code == indicatorsData.indicator_code

# """

showDF(AggIndicatorsData, truncate = False)

#number of rows should be the same as IndicatorsData
AggIndicatorsData.count()
# Out:
#    wb_country_code  indicator_code        1960        1961        1962  \
# 0   ARB             IT.NET.BBND    NaN         NaN         NaN
# 1   ARB             IT.CEL.SETS    NaN         NaN         NaN
# 2   ARB             SP.POP.0014.TO  39900284.0  41339703.0  42792877.0
# 3   ARB             SP.POP.1564.TO  49063244.0  50032198.0  51072095.0
# 4   ARB             SP.POP.65UP.TO  3234225.0   3352609.0   3469470.0
# 5   ARB             SP.POP.TOTL     92197753.0  94724510.0  97334442.0
# 6   CSS             IT.NET.BBND    NaN         NaN         NaN
# 7   CSS             IT.CEL.SETS    NaN         NaN         NaN
# 8   CSS             SP.POP.0014.TO  1764314.0   1813811.0   1861239.0
# 9   CSS             SP.POP.1564.TO  2150293.0   2172957.0   2197694.0
# 10  CSS             SP.POP.65UP.TO  168897.0    175068.0    181750.0
# 11  CSS             SP.POP.TOTL     4194710.0   4274060.0   4353628.0
# 12  CEB             IT.NET.BBND    NaN         NaN         NaN
# 13  CEB             IT.CEL.SETS    NaN         NaN         NaN
# 14  CEB             SP.POP.0014.TO  26671417.0  26777340.0  26719172.0
#
#            1963         1964         1965         1966         1967  ...  \
# 0  NaN          NaN          NaN          NaN          NaN           ...
# 1  NaN          NaN          NaN          NaN          NaN           ...
# 2   44248946.0   45685285.0   47089854.0   48668380.0   50184681.0   ...
# 3   52200457.0   53449205.0   54836642.0   56150911.0   57648467.0   ...
# 4   3584776.0    3698270.0    3809935.0    3939319.0    4066216.0    ...
# 5   100034179.0  102832760.0  105736431.0  108758610.0  111899364.0  ...
# 6  NaN          NaN          NaN          NaN          NaN           ...
# 7  NaN          NaN          NaN          NaN          NaN           ...
# 8   1905671.0    1946435.0    1983381.0    2024505.0    2062380.0    ...
# 9   2224438.0    2252268.0    2280020.0    2301103.0    2321443.0    ...
# 10  188665.0     195638.0     202721.0     208090.0     213636.0     ...
# 11  4432217.0    4508198.0    4580374.0    4648367.0    4712526.0    ...
# 12 NaN          NaN          NaN          NaN          NaN           ...
# 13 NaN          NaN          NaN          NaN          NaN           ...
# 14  26557292.0   26352149.0   26091982.0   25734869.0   25509198.0   ...
#
#            2011         2012         2013         2014          2015  \
# 0   8570787.0    10323586.0   8880291.0    10801834.0   1.808099e+07
# 1   351957968.0  381641858.0  407704505.0  415029432.0  4.190140e+08
# 2   121934515.0  124007632.0  126213709.0  128449757.0  1.306295e+08
# 3   226143306.0  231927215.0  237528428.0  242991668.0  2.483654e+08
# 4   15080882.0   15508701.0   15963579.0   16466321.0   1.703336e+07
# 5   363158703.0  371443547.0  379705719.0  387907748.0  3.960283e+08
# 6   498285.0     627251.0     674419.0     753368.0     8.971340e+05
# 7   7534114.0    7322041.0    7738401.0    7952805.0    8.158698e+06
# 8   1795979.0    1780360.0    1766078.0    1753161.0    1.741356e+06
# 9   4572902.0    4625875.0    4676979.0    4725564.0    4.771270e+06
# 10  533143.0     545579.0     558928.0     572851.0     5.872000e+05
# 11  7022387.0    7072665.0    7123332.0    7173435.0    7.222212e+06
# 12  20208640.0   20882334.0   21977753.0   22715875.0   2.335264e+07
# 13  131232764.0  135743131.0  137943652.0  136666800.0  1.313298e+08
# 14  15654422.0   15567230.0   15468931.0   15416915.0   1.543225e+07
#
#            2016         2017         2018  2019  \
# 0   20176081.0   28386768.0   29798964.0   None
# 1   417212258.0  416484374.0  392247081.0  None
# 2   133190635.0  135468682.0  137609185.0  None
# 3   253159511.0  258053167.0  263047867.0  None
# 4   17674286.0   18377118.0   19133535.0   None
# 5   404024433.0  411898965.0  419790588.0  None
# 6   971854.0     1003591.0    978363.0     None
# 7   8483364.0    8225309.0    7090967.0    None
# 8   1733031.0    1724190.0    1715606.0    None
# 9   4810378.0    4847980.0    4882863.0    None
# 10  603044.0     619315.0     636430.0     None
# 11  7269386.0    7314990.0    7358965.0    None
# 12  24104014.0   25139468.0   25380063.0   None
# 13  129855583.0  126579539.0  127547678.0  None
# 14  15357415.0   15405876.0   15515837.0   None
#
#                          indicator_name
# 0   Fixed broadband subscriptions
# 1   Mobile cellular subscriptions
# 2   Population ages 0-14, total
# 3   Population ages 15-64, total
# 4   Population ages 65 and above, total
# 5   Population, total
# 6   Fixed broadband subscriptions
# 7   Mobile cellular subscriptions
# 8   Population ages 0-14, total
# 9   Population ages 15-64, total
# 10  Population ages 65 and above, total
# 11  Population, total
# 12  Fixed broadband subscriptions
# 13  Mobile cellular subscriptions
# 14  Population ages 0-14, total
#
# [15 rows x 63 columns]
# 1584

# %% [markdown]
# #### The table above is not optimal. Years should be listed as rows instead of columns in case more data will be added in the future. I will start by listing the different years in this dataset

# %%
years = [x for x in AggIndicatorsData.schema.names \
             if x != 'wb_country_code' and x != 'indicator_code' and x != 'indicator_name'] 

print(years)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
#create a DataFrame with the same column names but no rows
indicatorsDF = indicatorsSample.filter('1 = 0')

#Iterate through the list of years and store each year as a row in the DataFrame created above
for indicatorYear in years:
    print("Processing indicators for " + indicatorYear)
    yearIndicatorDF = AggIndicatorsData \
        .select("wb_country_code",
                "indicator_code",
                F.lit(indicatorYear).alias("year"),
                F.col(indicatorYear).alias("indicator_value")) \
        .filter("indicator_value >= 0")
    indicatorsDF = indicatorsDF.union(yearIndicatorDF)
# Out:
# Processing indicators for 1960
# Processing indicators for 1961
# Processing indicators for 1962
# Processing indicators for 1963
# Processing indicators for 1964
# Processing indicators for 1965
# Processing indicators for 1966
# Processing indicators for 1967
# Processing indicators for 1968
# Processing indicators for 1969
# Processing indicators for 1970
# Processing indicators for 1971
# Processing indicators for 1972
# Processing indicators for 1973
# Processing indicators for 1974
# Processing indicators for 1975
# Processing indicators for 1976
# Processing indicators for 1977
# Processing indicators for 1978
# Processing indicators for 1979
# Processing indicators for 1980
# Processing indicators for 1981
# Processing indicators for 1982
# Processing indicators for 1983
# Processing indicators for 1984
# Processing indicators for 1985
# Processing indicators for 1986
# Processing indicators for 1987
# Processing indicators for 1988
# Processing indicators for 1989
# Processing indicators for 1990
# Processing indicators for 1991
# Processing indicators for 1992
# Processing indicators for 1993
# Processing indicators for 1994
# Processing indicators for 1995
# Processing indicators for 1996
# Processing indicators for 1997
# Processing indicators for 1998
# Processing indicators for 1999
# Processing indicators for 2000
# Processing indicators for 2001
# Processing indicators for 2002
# Processing indicators for 2003
# Processing indicators for 2004
# Processing indicators for 2005
# Processing indicators for 2006
# Processing indicators for 2007
# Processing indicators for 2008
# Processing indicators for 2009
# Processing indicators for 2010
# Processing indicators for 2011
# Processing indicators for 2012
# Processing indicators for 2013
# Processing indicators for 2014
# Processing indicators for 2015
# Processing indicators for 2016
# Processing indicators for 2017
# Processing indicators for 2018
# Processing indicators for 2019

# %%
showDF(indicatorsDF)

#cache the dataset 
indicatorsDF.cache()

#number of rows
indicatorsDF.count()
# Out:
#    wb_country_code  indicator_code  year  indicator_value
# 0              ARB  SP.POP.0014.TO  1960       39900284.0
# 1              ARB  SP.POP.1564.TO  1960       49063244.0
# 2              ARB  SP.POP.65UP.TO  1960        3234225.0
# 3              ARB     SP.POP.TOTL  1960       92197753.0
# 4              CSS  SP.POP.0014.TO  1960        1764314.0
# 5              CSS  SP.POP.1564.TO  1960        2150293.0
# 6              CSS  SP.POP.65UP.TO  1960         168897.0
# 7              CSS     SP.POP.TOTL  1960        4194710.0
# 8              CEB  SP.POP.0014.TO  1960       26671417.0
# 9              CEB  SP.POP.1564.TO  1960       58135802.0
# 10             CEB  SP.POP.65UP.TO  1960        6594545.0
# 11             CEB     SP.POP.TOTL  1960       91401764.0
# 12             EAR  SP.POP.0014.TO  1960      404035665.0
# 13             EAR  SP.POP.1564.TO  1960      543618346.0
# 14             EAR  SP.POP.65UP.TO  1960       32431246.0
# 72541

# %% [markdown]
# #### Check the indicator counts per year

# %%
#Register the DataFrame as a global temporary view for SQL queries
indicatorsDF.createOrReplaceTempView("indicatorsDF")

# %%
indicatorCount = """

select
    year,
    count(1) as count
from
    indicatorsDF
group by
    year
order by
    year

"""

showDF(spark.sql(indicatorCount))
# Out:
#     year  count
# 0   1960   1174
# 1   1961    974
# 2   1962    974
# 3   1963    974
# 4   1964    974
# 5   1965   1174
# 6   1966    974
# 7   1967    974
# 8   1968    974
# 9   1969    974
# 10  1970   1174
# 11  1971    974
# 12  1972    974
# 13  1973    974
# 14  1974    974

# %% [markdown]
# #### Get yearly indicator totals and rename columns

# %%
yearPivot = indicatorsDF \
    .groupBy('year') \
    .pivot('indicator_code') \
    .sum('indicator_value') \
    .orderBy('year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population')

showDF(yearPivot)
# Out:
#     year  cellular_subscriptions broadband_subscriptions  \
# 0   1960                     0.0                    None
# 1   1961                     NaN                    None
# 2   1962                     NaN                    None
# 3   1963                     NaN                    None
# 4   1964                     NaN                    None
# 5   1965                     0.0                    None
# 6   1966                     NaN                    None
# 7   1967                     NaN                    None
# 8   1968                     NaN                    None
# 9   1969                     NaN                    None
# 10  1970                     0.0                    None
# 11  1971                     NaN                    None
# 12  1972                     NaN                    None
# 13  1973                     NaN                    None
# 14  1974                     NaN                    None
#
#     population_age_0_to_14  population_age_15_64  population_age_65_and_above  \
# 0             1.165480e+10          1.761082e+10                 1.417300e+09
# 1             1.187328e+10          1.777136e+10                 1.449380e+09
# 2             1.216371e+10          1.799833e+10                 1.481571e+09
# 3             1.250560e+10          1.830696e+10                 1.515232e+09
# 4             1.282141e+10          1.864850e+10                 1.547347e+09
# 5             1.310614e+10          1.903849e+10                 1.579097e+09
# 6             1.343282e+10          1.940264e+10                 1.632302e+09
# 7             1.370951e+10          1.981464e+10                 1.685198e+09
# 8             1.395921e+10          2.026739e+10                 1.737935e+09
# 9             1.421320e+10          2.075248e+10                 1.791344e+09
# 10            1.447520e+10          2.124201e+10                 1.843743e+09
# 11            1.477153e+10          2.170601e+10                 1.907999e+09
# 12            1.505245e+10          2.217761e+10                 1.969850e+09
# 13            1.531996e+10          2.265902e+10                 2.029781e+09
# 14            1.556671e+10          2.316366e+10                 2.089703e+09
#
#       population
# 0   3.069726e+10
# 1   3.110865e+10
# 2   3.165863e+10
# 3   3.234320e+10
# 4   3.303306e+10
# 5   3.373993e+10
# 6   3.448434e+10
# 7   3.522633e+10
# 8   3.598191e+10
# 9   3.677480e+10
# 10  3.757912e+10
# 11  3.840409e+10
# 12  3.921889e+10
# 13  4.002814e+10
# 14  4.083987e+10

# %% [markdown]
# #### Inspect the schema

# %%
yearPivot.printSchema()
# Out:
# root
#  |-- year: string (nullable = false)
#  |-- cellular_subscriptions: double (nullable = true)
#  |-- broadband_subscriptions: double (nullable = true)
#  |-- population_age_0_to_14: double (nullable = true)
#  |-- population_age_15_64: double (nullable = true)
#  |-- population_age_65_and_above: double (nullable = true)
#  |-- population: double (nullable = true)

# %% [markdown]
# ### Data Quality Check

# %%
#cache the dataset
yearPivot.cache()

#number of rows
yearPivot.count()
# Out:
# 59

# %% [markdown]
# #### Checking for negative values and if the population samples are greater than the entire population. The values below should be 0

# %%
yearPivot.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yearPivot.filter('population_age_65_and_above > population').count()
# Out:
# 0

# %%
yearPivot.filter('population_age_15_64 > population').count()
# Out:
# 0

# %%
yearPivot.filter('population_age_0_to_14 > population').count()
# Out:
# 0

# %%
yearPivot.filter('broadband_subscriptions < 0').count()
# Out:
# 0

# %%
yearPivot.filter('cellular_subscriptions < 0').count()
# Out:
# 0

# %%
yearPivot.filter('population < 0').count()
# Out:
# 0

# %%
yearPivot.filter('population_age_65_and_above < 0').count()
# Out:
# 0

# %%
yearPivot.filter('population_age_15_64 < 0').count()
# Out:
# 0

# %%
yearPivot.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yearPivot.filter('(population_age_0_to_14 + population_age_15_64 + population_age_65_and_above) > population').count()
# Out:
# 0

# %% [markdown]
# #### Write yearPivot as a csv file to the folder

# %%
yearPivot \
    .select('year',
            F.col('population').cast(DecimalType(38, 2)),
            F.col('population_age_0_to_14').cast(DecimalType(38, 2)),
            F.col('population_age_15_64').cast(DecimalType(38, 2)),
            F.col('population_age_65_and_above').cast(DecimalType(38, 2)),
            F.col('broadband_subscriptions').cast(DecimalType(38, 2)),
            F.col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('./Downloads/WDI_csv/Final/yearlyStats', mode='overwrite', header='true')

# %% [markdown]
# #### Get yearly regional totals

# %%
#joining indicatorsDF with countryFinal by wb_country_code
regionalIndicators = indicatorsDF.join(countryFinal,
                                       indicatorsDF.wb_country_code == countryRenamed.wb_country_code, "inner") \
    .select(countryRenamed.region,
            indicatorsDF.wb_country_code,
            indicatorsDF.year,
            indicatorsDF.indicator_code,
            indicatorsDF.indicator_value)

#SQL equivalent
# select 
#     countryFinal.region,
#     indicatorsDF.wb_country_code,
#     indicatorsDF.year,
#     indicatorsDF.indicator_code,
#     indicatorsDF.indicator_value
# from 
#     countryFinal
# inner join
#     indicatorsDF on countryFinal.wb_country_code == indicatorsDF.wb_country_code

showDF(regionalIndicators)
# Out:
#    region wb_country_code  year  indicator_code  indicator_value
# 0    None             ARB  1960  SP.POP.0014.TO       39900284.0
# 1    None             ARB  1960  SP.POP.1564.TO       49063244.0
# 2    None             ARB  1960  SP.POP.65UP.TO        3234225.0
# 3    None             ARB  1960     SP.POP.TOTL       92197753.0
# 4    None             CSS  1960  SP.POP.0014.TO        1764314.0
# 5    None             CSS  1960  SP.POP.1564.TO        2150293.0
# 6    None             CSS  1960  SP.POP.65UP.TO         168897.0
# 7    None             CSS  1960     SP.POP.TOTL        4194710.0
# 8    None             CEB  1960  SP.POP.0014.TO       26671417.0
# 9    None             CEB  1960  SP.POP.1564.TO       58135802.0
# 10   None             CEB  1960  SP.POP.65UP.TO        6594545.0
# 11   None             CEB  1960     SP.POP.TOTL       91401764.0
# 12   None             EAR  1960  SP.POP.0014.TO      404035665.0
# 13   None             EAR  1960  SP.POP.1564.TO      543618346.0
# 14   None             EAR  1960  SP.POP.65UP.TO       32431246.0

# %% [markdown]
# #### Pivot the table above so it is horizontal

# %%
regionalPivot = regionalIndicators \
    .groupBy('region', 'year') \
    .pivot('indicator_code') \
    .sum('indicator_value') \
    .orderBy('region', 'year')

showDF(regionalPivot)
# Out:
#    region  year IT.CEL.SETS IT.NET.BBND  SP.POP.0014.TO  SP.POP.1564.TO  \
# 0    None  1960        None        None    1.053508e+10    1.586715e+10
# 1    None  1961        None        None    1.073303e+10    1.601107e+10
# 2    None  1962        None        None    1.099691e+10    1.621549e+10
# 3    None  1963        None        None    1.130783e+10    1.649399e+10
# 4    None  1964        None        None    1.159509e+10    1.680246e+10
# 5    None  1965        None        None    1.185411e+10    1.715510e+10
# 6    None  1966        None        None    1.215137e+10    1.748452e+10
# 7    None  1967        None        None    1.240321e+10    1.785753e+10
# 8    None  1968        None        None    1.263068e+10    1.826790e+10
# 9    None  1969        None        None    1.286192e+10    1.870709e+10
# 10   None  1970        None        None    1.310057e+10    1.915049e+10
# 11   None  1971        None        None    1.337065e+10    1.957011e+10
# 12   None  1972        None        None    1.362676e+10    1.999679e+10
# 13   None  1973        None        None    1.387082e+10    2.043261e+10
# 14   None  1974        None        None    1.409603e+10    2.088911e+10
#
#     SP.POP.65UP.TO   SP.POP.TOTL
# 0     1.267373e+09  2.768255e+10
# 1     1.295999e+09  2.805330e+10
# 2     1.324760e+09  2.855071e+10
# 3     1.354860e+09  2.917059e+10
# 4     1.383554e+09  2.979536e+10
# 5     1.411916e+09  3.043575e+10
# 6     1.459688e+09  3.111055e+10
# 7     1.507189e+09  3.178327e+10
# 8     1.554569e+09  3.246884e+10
# 9     1.602500e+09  3.318756e+10
# 10    1.649534e+09  3.391699e+10
# 11    1.707208e+09  3.466471e+10
# 12    1.762748e+09  3.540344e+10
# 13    1.816587e+09  3.613752e+10
# 14    1.870377e+09  3.687339e+10

# %% [markdown]
# #### Rename columns and write regionalPivot as a csv to the folder

# %%
#Write the regional-yearly totals to a CSV File
regionalPivot \
    .filter('region is not null') \
    .orderBy('region','year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select('region',
            'year',
            F.col('population').cast(DecimalType(38, 2)),
            F.col('population_age_0_to_14').cast(DecimalType(38, 2)),
            F.col('population_age_15_64').cast(DecimalType(38, 2)),
            F.col('population_age_65_and_above').cast(DecimalType(38, 2)),
            F.col('broadband_subscriptions').cast(DecimalType(38, 2)),
            F.col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('./Downloads/WDI_csv/Final/regionalStats', mode='overwrite', header='true')

# %% [markdown]
# #### After finding regional statistics, I will do the same for countries

# %%
countryIndicators = indicatorsDF.join(countryFinal,
                                      indicatorsDF.wb_country_code == countryRenamed.wb_country_code, "inner") \
    .select(indicatorsDF.wb_country_code,
            countryRenamed.country_iso_code,
            countryRenamed.country_name,
            indicatorsDF.year,
            indicatorsDF.indicator_code,
            indicatorsDF.indicator_value)

# SQL equivalent
# select 
#     indicatorsDF.wb_country_code,
#     countryFinal.country_iso_code,
#     countryFinal.country_name,
#     indicatorsDF.year,
#     indicatorsDF.indicator_code,
#     indicatorsDF.indicator_value
# from 
#     countryFinal
# inner join
#     indicatorsDF on countryFinal.wb_country_code == indicatorsDF.wb_country_code

showDF(countryIndicators)
# Out:
#    wb_country_code country_iso_code                    country_name  year  \
# 0              ARB               1A                      Arab World  1960
# 1              ARB               1A                      Arab World  1960
# 2              ARB               1A                      Arab World  1960
# 3              ARB               1A                      Arab World  1960
# 4              CSS               S3          Caribbean small states  1960
# 5              CSS               S3          Caribbean small states  1960
# 6              CSS               S3          Caribbean small states  1960
# 7              CSS               S3          Caribbean small states  1960
# 8              CEB               B8  Central Europe and the Baltics  1960
# 9              CEB               B8  Central Europe and the Baltics  1960
# 10             CEB               B8  Central Europe and the Baltics  1960
# 11             CEB               B8  Central Europe and the Baltics  1960
# 12             EAR               V2      Early-demographic dividend  1960
# 13             EAR               V2      Early-demographic dividend  1960
# 14             EAR               V2      Early-demographic dividend  1960
#
#     indicator_code  indicator_value
# 0   SP.POP.0014.TO       39900284.0
# 1   SP.POP.1564.TO       49063244.0
# 2   SP.POP.65UP.TO        3234225.0
# 3      SP.POP.TOTL       92197753.0
# 4   SP.POP.0014.TO        1764314.0
# 5   SP.POP.1564.TO        2150293.0
# 6   SP.POP.65UP.TO         168897.0
# 7      SP.POP.TOTL        4194710.0
# 8   SP.POP.0014.TO       26671417.0
# 9   SP.POP.1564.TO       58135802.0
# 10  SP.POP.65UP.TO        6594545.0
# 11     SP.POP.TOTL       91401764.0
# 12  SP.POP.0014.TO      404035665.0
# 13  SP.POP.1564.TO      543618346.0
# 14  SP.POP.65UP.TO       32431246.0

# %% [markdown]
# #### Pivot the table so it is horizontal

# %%
countryPivot = countryIndicators \
    .groupBy('country_iso_code', 'country_name', 'year') \
    .pivot('indicator_code') \
    .sum('indicator_value')

showDF(countryPivot)
# Out:
#    country_iso_code                                 country_name  year  \
# 0                NG                                      Nigeria  2007
# 1                AR                                    Argentina  2016
# 2                LS                                      Lesotho  1970
# 3                CD                              Dem. Rep. Congo  1963
# 4                FR                                       France  1971
# 5                GN                                       Guinea  1980
# 6                BA                       Bosnia and Herzegovina  1990
# 7                4E  East Asia & Pacific (excluding high income)  1994
# 8                TD                                         Chad  2015
# 9                TL                                  Timor-Leste  2014
# 10               DO                           Dominican Republic  2015
# 11               GH                                        Ghana  1972
# 12               1W                                        World  1988
# 13               GW                                Guinea-Bissau  1991
# 14               CW                                      Curaçao  2012
#
#     IT.CEL.SETS  IT.NET.BBND  SP.POP.0014.TO  SP.POP.1564.TO  SP.POP.65UP.TO  \
# 0    40395611.0      53594.0    6.422666e+07    7.807074e+07       4042581.0
# 1    63719805.0    7223128.0    1.093223e+07    2.792424e+07       4733904.0
# 2           0.0          NaN    4.661950e+05    5.176780e+05         45053.0
# 3           NaN          NaN    7.154849e+06    8.829594e+06        477387.0
# 4           NaN          NaN    1.291223e+07    3.263716e+07       6821956.0
# 5           0.0          NaN    2.108557e+06    2.603388e+06        159490.0
# 6           0.0          NaN    1.078368e+06    3.091144e+06        293911.0
# 7     3155452.0          NaN    5.011778e+08    1.101605e+09      93570036.0
# 8     5465797.0      11337.0    6.750220e+06    7.015783e+06        344972.0
# 9     1375749.0       1028.0    4.707270e+05    6.523390e+05         51265.0
# 10    8797247.0     686107.0    2.964047e+06    6.648324e+06        669309.0
# 11          NaN          NaN    4.327882e+06    4.670168e+06        231581.0
# 12    4327956.0          NaN    1.696258e+09    3.094436e+09     309072915.0
# 13          0.0          NaN    4.639220e+05    5.005800e+05         33020.0
# 14     204702.0      35582.0    3.076100e+04    1.003310e+05         20996.0
#
#      SP.POP.TOTL
# 0   1.463400e+08
# 1   4.359037e+07
# 2   1.028926e+06
# 3   1.646183e+07
# 4   5.237134e+07
# 5   4.871435e+06
# 6   4.463423e+06
# 7   1.696475e+09
# 8   1.411098e+07
# 9   1.174331e+06
# 10  1.028168e+07
# 11  9.229631e+06
# 12  5.102293e+09
# 13  9.975220e+05
# 14  1.520880e+05

# %% [markdown]
# #### Rename columns and write countryPivot as a csv to the folder

# %%
countryPivot.filter('country_iso_code is not null') \
    .orderBy('country_iso_code','country_name', 'year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select('country_iso_code',
            'country_name',
            'year',
            F.col('population').cast(DecimalType(38, 2)),
            F.col('population_age_0_to_14').cast(DecimalType(38, 2)),
            F.col('population_age_15_64').cast(DecimalType(38, 2)),
            F.col('population_age_65_and_above').cast(DecimalType(38, 2)),
            F.col('broadband_subscriptions').cast(DecimalType(38, 2)),
            F.col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('./Downloads/WDI_csv/Final/countryStats', mode='overwrite', header='true')

# %% [markdown]
# ### Business Startup Metrics

# %% [markdown]
# To identify countries that are conductive to start a business, I will consider the most recent metrics for the following:
# - Gross National Income (GNI)
# - Cost of business start-up procedures
# - Number of days required to start a business
# - Number of start-up procedures to register a business
# - GDP
# - GDP per capita
# - Business Regulatory Environment
# - Ease of doing business index

# %%
recentIndicators = indicatorsData \
    .select("wb_country_code", "indicator_code", "2018") \
    .filter(F.col('indicator_code').isin('IC.REG.COST.PC.ZS', 'IC.REG.DURS', 'IC.REG.PROC', \
        'NY.GNP.ATLS.CD', 'NY.GDP.MKTP.KD', 'NY.GDP.PCAP.KD', 'IQ.CPA.BREG.XQ', 'IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2018", "indicator_value") \
    .withColumn("indicator_value", F.col("indicator_value").cast(DecimalType(38, 2)))

showDF(recentIndicators)
# Out:
#    wb_country_code     indicator_code   indicator_value
# 0              ARB  IC.REG.COST.PC.ZS              8.61
# 1              ARB     IQ.CPA.BREG.XQ              2.90
# 2              ARB     IC.BUS.EASE.XQ              None
# 3              ARB     NY.GDP.MKTP.KD  2708687562213.17
# 4              ARB     NY.GDP.PCAP.KD           6452.47
# 5              ARB     NY.GNP.ATLS.CD  2672906114477.03
# 6              ARB        IC.REG.PROC              7.32
# 7              ARB        IC.REG.DURS             20.67
# 8              CSS  IC.REG.COST.PC.ZS              None
# 9              CSS     IQ.CPA.BREG.XQ              3.40
# 10             CSS     IC.BUS.EASE.XQ              None
# 11             CSS     NY.GDP.MKTP.KD    65932478307.76
# 12             CSS     NY.GDP.PCAP.KD           8959.48
# 13             CSS     NY.GNP.ATLS.CD    67997467061.95
# 14             CSS        IC.REG.PROC              6.62

# %%
businessIndexIndicators = indicatorsData \
    .select("wb_country_code", "indicator_code", "2019") \
    .filter(F.col('indicator_code').isin('IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2019", "indicator_value") \
    .withColumn("indicator_value", F.col("indicator_value").cast(DecimalType(38, 2)))

showDF(businessIndexIndicators)
# Out:
#    wb_country_code  indicator_code indicator_value
# 0              ARB  IC.BUS.EASE.XQ            None
# 1              CSS  IC.BUS.EASE.XQ            None
# 2              CEB  IC.BUS.EASE.XQ            None
# 3              EAR  IC.BUS.EASE.XQ            None
# 4              EAS  IC.BUS.EASE.XQ            None
# 5              EAP  IC.BUS.EASE.XQ            None
# 6              TEA  IC.BUS.EASE.XQ            None
# 7              EMU  IC.BUS.EASE.XQ            None
# 8              ECS  IC.BUS.EASE.XQ            None
# 9              ECA  IC.BUS.EASE.XQ            None
# 10             TEC  IC.BUS.EASE.XQ            None
# 11             EUU  IC.BUS.EASE.XQ            None
# 12             FCS  IC.BUS.EASE.XQ            None
# 13             HPC  IC.BUS.EASE.XQ            None
# 14             HIC  IC.BUS.EASE.XQ            None

# %%
allIndicators = recentIndicators.union(businessIndexIndicators)
showDF(allIndicators)
# Out:
#    wb_country_code     indicator_code   indicator_value
# 0              ARB  IC.REG.COST.PC.ZS              8.61
# 1              ARB     IQ.CPA.BREG.XQ              2.90
# 2              ARB     IC.BUS.EASE.XQ              None
# 3              ARB     NY.GDP.MKTP.KD  2708687562213.17
# 4              ARB     NY.GDP.PCAP.KD           6452.47
# 5              ARB     NY.GNP.ATLS.CD  2672906114477.03
# 6              ARB        IC.REG.PROC              7.32
# 7              ARB        IC.REG.DURS             20.67
# 8              CSS  IC.REG.COST.PC.ZS              None
# 9              CSS     IQ.CPA.BREG.XQ              3.40
# 10             CSS     IC.BUS.EASE.XQ              None
# 11             CSS     NY.GDP.MKTP.KD    65932478307.76
# 12             CSS     NY.GDP.PCAP.KD           8959.48
# 13             CSS     NY.GNP.ATLS.CD    67997467061.95
# 14             CSS        IC.REG.PROC              6.62

# %% [markdown]
# #### Rename and columns and filter out null values

# %%
countryBusinessStartupPivot = allIndicators.join(countryFinal
                                       , recentIndicators.wb_country_code == countryRenamed.wb_country_code
                                       , "inner") \
    .select(countryFinal.country_iso_code
            , countryFinal.country_name
            , recentIndicators.indicator_code
            , recentIndicators.indicator_value) \
    .groupBy('country_iso_code', 'country_name').pivot('indicator_code').sum('indicator_value') \
    .withColumnRenamed('NY.GNP.ATLS.CD', 'GNI') \
    .withColumnRenamed('IC.REG.DURS', 'Startup Time') \
    .withColumnRenamed('IC.REG.PROC', 'Startup Procedures') \
    .withColumnRenamed('IC.REG.COST.PC.ZS', 'Startup Cost Pct of GNI') \
    .withColumnRenamed('NY.GDP.MKTP.KD', 'GDP') \
    .withColumnRenamed('NY.GDP.PCAP.KD', 'GDP Per Capita') \
    .withColumnRenamed('IQ.CPA.BREG.XQ', 'Business Regulation') \
    .withColumnRenamed('IC.BUS.EASE.XQ', 'Ease of business') \
    .withColumn('Startup Cost', (F.col('GNI') * F.col('Startup Cost Pct of GNI') / F.lit(100.0)).cast(DecimalType(38, 2))) \
    .filter(F.col('GNI') > 0) \
    .filter(F.col('Startup Time').isNotNull()) \
    .filter(F.col('Startup Procedures').isNotNull()) \
    .filter(F.col('Startup Cost').isNotNull())

showDF(countryBusinessStartupPivot)
# Out:
#    country_iso_code                            country_name Ease of business  \
# 0                BJ                                   Benin           149.00
# 1                XC                               Euro area             None
# 2                LY                                   Libya           186.00
# 3                KZ                              Kazakhstan            25.00
# 4                JM                                 Jamaica            71.00
# 5                NO                                  Norway             9.00
# 6                AG                     Antigua and Barbuda           113.00
# 7                CG                                   Congo           180.00
# 8                AR                               Argentina           126.00
# 9                HT                                   Haiti           179.00
# 10               QA                                   Qatar            77.00
# 11               EU                          European Union             None
# 12               XE  Heavily indebted poor countries (HIPC)             None
# 13               BB                                Barbados           128.00
# 14               LT                               Lithuania            11.00
#
#    Startup Cost Pct of GNI Startup Time Startup Procedures  \
# 0                     5.20         8.50               6.00
# 1                     9.57        10.45               5.32
# 2                    26.60        35.00              10.00
# 3                     0.00         5.00               5.00
# 4                     0.00         3.00               2.00
# 5                     4.60         4.00               4.00
# 6                     0.00        22.00               9.00
# 7                     2.90        49.50              11.00
# 8                     0.00        11.00              11.00
# 9                    12.40        97.00              12.00
# 10                    0.00         8.70               8.00
# 11                    9.57        12.96               5.54
# 12                   11.96        23.03               7.31
# 13                    0.00        16.00               7.00
# 14                   17.50         5.50               4.00
#
#    Business Regulation                GDP GDP Per Capita                GNI  \
# 0                 3.50     10304371091.90         897.20     10029263429.42
# 1                 None  13996985489820.40       40952.82  13252466851547.40
# 2                 None     50334718705.94        7536.75     42771026208.70
# 3                 None    204067060294.54       11165.54    147572879547.56
# 4                 None     14249490164.85        4855.26     14582302023.57
# 5                 None    489331167946.42       92077.57    428375207614.42
# 6                 None      1457277455.93       15134.88      1530376688.84
# 7                 2.00     13906481140.14        2651.70      8613989208.89
# 8                 None    446880911357.64       10043.51    551170581779.71
# 9                 1.50      8123218871.20         730.30      8913582852.36
# 10                None    175970440575.36       63260.56    170097430243.30
# 11                None  19231570999562.80       37472.86  18177922747803.50
# 12                2.93    706595610993.11         905.62    722376365292.22
# 13                None      4591427326.59       16018.04      4417327947.21
# 14                None     49398523336.85       17708.53     48634196073.51
#
#         Startup Cost
# 0       521521698.33
# 1   1268261077693.09
# 2     11377092971.51
# 3               0.00
# 4               0.00
# 5     19705259550.26
# 6               0.00
# 7       249805687.06
# 8               0.00
# 9      1105284273.69
# 10              0.00
# 11  1739627206964.80
# 12    86396213288.95
# 13              0.00
# 14     8510984312.86

# %% [markdown]
# #### Save countryBusinessStartupPivot as a csv file to the folder

# %%
countryBusinessStartupPivot \
    .select("country_iso_code", "country_name", "GDP", "GDP Per Capita", "GNI", \
            "Startup Cost", "Startup Cost Pct of GNI", "Startup Time", "Startup Procedures", \
            "Business Regulation", "Ease of business") \
    .coalesce(1) \
    .write.csv('./Downloads/WDI_csv/Final/StartupData', mode='overwrite', header='true')
